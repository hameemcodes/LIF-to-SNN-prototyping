# %%
# %matplotlib inline
import brian2 as b2
import matplotlib.pyplot as plt
import numpy as np
from neurodynex3.leaky_integrate_and_fire import LIF
from neurodynex3.tools import input_factory, plot_tools


LIF.getting_started()
LIF.print_default_parameters()
# Out:
# nr of spikes: 0
# nr of spikes: 5
# Resting potential: -70. mV
# Reset voltage: -65. mV
# Firing threshold: -50. mV
# Membrane resistance: 10. Mohm
# Membrane time-scale: 8. ms
# Absolute refractory period: 2. ms
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 11
#       7
#       8
#       9 LIF.getting_started()
#      10 LIF.print_default_parameters()
# ---> 11 LIF.help
#      12
#
# AttributeError: module 'neurodynex3.leaky_integrate_and_fire.LIF' has no attribute 'help'

# %%
# creating a step current with amplitude = 2nA = I_min
step_current = input_factory.get_step_current(
    t_start = 5, t_end = 100, unit_time=b2.ms, amplitude = 2*b2.nA)

#running LIF model

(state_monitor, spike_monitor) = LIF.simulate_LIF_neuron(input_current = step_current, simulation_time = 100*b2.ms)

#plot I and vm

plot_tools.plot_voltage_and_current_traces(
    state_monitor, step_current, title="min input", firing_threshold=LIF.FIRING_THRESHOLD)
print("nr of spikes:{}".format(spike_monitor.count[0]))
# Out:
# nr of spikes:0
